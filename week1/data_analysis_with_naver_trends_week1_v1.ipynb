# %%
#-*- coding: utf-8 -*-
import pandas as pd
import numpy as np
import os
import sys
import urllib.request
client_id = "6hZtUpcvDePLuIsHeaxe"
client_secret = "3mo9H2Bc0B"
url = "https://openapi.naver.com/v1/datalab/search";

group1Name = '제주도여행'
group1_mem1 =  '제주도여행'
group1_mem2 =  '제주여행'

group2Name = '부산여행'
group2_mem1 =  '부산여행'
group2_mem2 =  '부산관광'

group3Name = '서울여행'
group3_mem1 =  '서울여행'
group3_mem2 =  '서울관광'

group4Name = '인천여행'
group4_mem1 =  '인천여행'
group4_mem2 =  '인천관광'

group5Name = '단양여행'
group5_mem1 =  '단양여행'
group5_mem2 =  '단양관광'



body = "{\"startDate\":\"2019-01-01\",\"endDate\":\"2021-08-30\",\"timeUnit\":\"date\",\"keywordGroups\":[{\"groupName\":\"%s\",\"keywords\":[\"%s\",\"%s\"]},{\"groupName\":\"%s\",\"keywords\":[\"%s\",\"%s\"]},{\"groupName\":\"%s\",\"keywords\":[\"%s\",\"%s\"]},{\"groupName\":\"%s\",\"keywords\":[\"%s\",\"%s\"]},{\"groupName\":\"%s\",\"keywords\":[\"%s\",\"%s\"]}],\"device\":\"pc\",\"ages\":[\"1\",\"2\"],\"gender\":\"f\"}"%(f'{group1Name}', f'{group1_mem1}', f'{group1_mem2}', f'{group2Name}', f'{group2_mem1}', f'{group2_mem2}',f'{group3Name}', f'{group3_mem1}', f'{group3_mem2}', f'{group4Name}', f'{group4_mem1}', f'{group4_mem2}', f'{group5Name}', f'{group5_mem1}', f'{group5_mem2}');

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {"startDate":"2019-01-01","endDate":"2021-08-30","timeUnit":"date","results":[{"title":"제주도여행","keywords":["제주도여행","제주여행"],"data":[{"period":"2019-01-01","ratio":12.5},{"period":"2019-01-02","ratio":7.5},{"period":"2019-01-03","ratio":20},{"period":"2019-01-04","ratio":17.5},{"period":"2019-01-05","ratio":2.5},{"period":"2019-01-06","ratio":22.5},{"period":"2019-01-08","ratio":17.5},{"period":"2019-01-09","ratio":17.5},{"period":"2019-01-10","ratio":27.5},{"period":"2019-01-11","ratio":27.5},{"period":"2019-01-12","ratio":2.5},{"period":"2019-01-13","ratio":10},{"period":"2019-01-14","ratio":30},{"period":"2019-01-15","ratio":10},{"period":"2019-01-16","ratio":17.5},{"period":"2019-01-17","ratio":10},{"period":"2019-01-18","ratio":17.5},{"period":"2019-01-19","ratio":7.5},{"period":"2019-01-20","ratio":12.5},{"period":"2019-01-21","ratio":15},{"period":"2019-01-22","ratio":25},{"period":"2019-01-23","ratio":30},{"period":"2019-01-24","ratio":12.5},{"period":"2019-01-25","ratio":15},{
# ...

# %%
import nltk
nltk.download('punkt')
sentence = """At eight o'clock on Thursday morning
... Arthur didn't feel very good."""
tokens = nltk.word_tokenize(sentence)
tokens
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Bonghwan\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# ['At',
#  'eight',
#  "o'clock",
#  'on',
#  'Thursday',
#  'morning',
#  '...',
#  'Arthur',
#  'did',
#  "n't",
#  'feel',
#  'very',
#  'good',
#  '.']

# %%
# !pip install konlpy
# Out:
# ...
#   Using cached beautifulsoup4-4.6.0-py3-none-any.whl (86 kB)
# ...
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.4.1
#     Uninstalling beautifulsoup4-4.4.1:
#       Successfully uninstalled beautifulsoup4-4.4.1
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# html-table-parser 0.1.0 requires beautifulsoup4==4.4.1, but you have beautifulsoup4 4.6.0 which is incompatible.

# %%
from konlpy.tag import Okt
okt = Okt()
tokens_naver = nltk.word_tokenize(response_body.decode('utf-8'))
tokens_naver
# Out:
# ['{',
#  '``',
#  'startDate',
#  "''",
#  ':',
#  "''",
#  '2019-01-01',
#  "''",
#  ',',
#  "''",
#  'endDate',
#  "''",
#  ':',
#  "''",
#  '2021-08-30',
#  "''",
#  ',',
#  "''",
#  'timeUnit',
#  "''",
#  ':',
#  "''",
#  'date',
#  "''",
#  ',',
#  "''",
#  'results',
#  "''",
#  ':',
#  '[',
#  '{',
#  '``',
#  'title',
#  "''",
#  ':',
#  "''",
#  '제주도여행',
#  "''",
#  ',',
#  "''",
#  'keywords',
#  "''",
#  ':',
#  '[',
#  '``',
#  '제주도여행',
#  "''",
#  ',',
#  "''",
#  '제주여행',
#  "''",
#  ']',
#  ',',
#  "''",
#  'data',
#  "''",
#  ':',
#  '[',
#  '{',
#  '``',
#  'period',
#  "''",
#  ':',
#  "''",
#  '2019-01-01',
#  "''",
#  ',',
#  "''",
#  'ratio',
#  "''",
#  ':12.5',
#  '}',
#  ',',
#  '{',
#  '``',
#  'period',
#  "''",
#  ':',
#  "''",
#  '2019-01-02',
#  "''",
#  ',',
#  "''",
#  'ratio',
#  "''",
#  ':7.5',
#  '}',
#  ',',
#  '{',
#  '``',
#  'period',
#  "''",
#  ':',
#  "''",
#  '2019-01-03',
#  "''",
#  ',',
#  "''",
#  'ratio',
#  "''",
#  ':20',
#  '}',
# ...

# %%
c_list = []
for c, i in enumerate(tokens_naver):
  # if '2019' in i or '2018' in i or '2020' in i or '2021' in i:
  #   print(i)
  # if type(i) == str:
  #   print(i)
  # if '단양' in i:
  #   print(c)
  # if c > 43551:
    # print(i)
  # if 'ratio' in i:
  #   # print(c)
  #   ## 이때의 c(아마 c+2이겠지?)를 리스트에 넣고, 이후 if c in c_list 일 때 프린트 한다던지 해서 확인 가능
  #   if c == 46315:
  #     print(i)
  # if c == 46315:
  #     print(i)
  if 'ratio' in i:
    c_list.append(c+2)

# %%
for c,i in enumerate(tokens_naver):
  if c in c_list:
    print(i)
# Out:
# :12.5
# :7.5
# :20
# :17.5
# :2.5
# :22.5
# :17.5
# :17.5
# :27.5
# :27.5
# :2.5
# :10
# :30
# :10
# :17.5
# :10
# :17.5
# :7.5
# :12.5
# :15
# :25
# :30
# :12.5
# :15
# :15
# :12.5
# :22.5
# :22.5
# :15
# :12.5
# :17.5
# :30
# :10
# :2.5
# :2.5
# :30
# :17.5
# :15
# :15
# :22.5
# :25
# :17.5
# :37.5
# :2.5
# :17.5
# :12.5
# :15
# :20
# :15
# :15
# :15
# :12.5
# :7.5
# :10
# :10
# :15
# :10
# :2.5
# :7.5
# :7.5
# :7.5
# :2.5
# :5
# :7.5
# :15
# :2.5
# :2.5
# :7.5
# :5
# :2.5
# :5
# :10
# :17.5
# :20
# :25
# :20
# :10
# :12.5
# :12.5
# :5
# :30
# :25
# :7.5
# :12.5
# :10
# :32.5
# :22.5
# :7.5
# :30
# :10
# :20
# :7.5
# :20
# :10
# :15
# :10
# :20
# :15
# :32.5
# :25
# :7.5
# :7.5
# :17.5
# :27.5
# :20
# :17.5
# :17.5
# :10
# :5
# :2.5
# :22.5
# :12.5
# :22.5
# :5
# :17.5
# :7.5
# :10
# :25
# :10
# :10
# :15
# :7.5
# :5
# :22.5
# :10
# :17.5
# :2.5
# :12.5
# :2.5
# :42.5
# :37.5
# :5
# :20
# :12.5
# :12.5
# :10
# :35
# :20
# :22.5
# :22.5
# :25
# :12.5
# :12.5
# :32.5
# :50
# :35
# ...
